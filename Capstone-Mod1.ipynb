# %% [markdown]
# <h1>This Notebook will be for the Capstone Project</h1>

# %%
import pandas as pd
import numpy as np

print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
